# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Importing Data

# %%
data_path = r'C:\Users\gerar\CareerFoundry Python\Spotify charts streaming analysis'
df_spotify_raw = pd.read_csv(os.path.join(data_path, '02 Data', 'Original Data', 'final.csv'), index_col = False, low_memory = False)
#df_spotify_raw_test = pd.read_csv(r'C:/Users/gerar\CareerFoundry Python\Spotify charts streaming analysis\02 Data')

# %%
df_spotify_raw.shape
# Out:
# (1787999, 36)

# %%
### Row and column settings ### 
pd.options.display.max_columns = 30
pd.options.display.max_rows = 20

# %%
df_spotify_raw.head().T
# Out:
#                                                  0  \
# Unnamed: 0                                       0
# uri           spotify:track:2gpQi3hbcUAcEG8m2dlgfB
# rank                                             1
# artist_names                          Paulo Londra
# artists_num                                    1.0
# ...                                            ...
# duration                                  178203.0
# country                                  Argentina
# region                               South America
# language                                   Spanish
# pivot                                            0
#
#                                                  1  \
# Unnamed: 0                                       1
# uri           spotify:track:2x8oBuYaObjqHqgGuIUZ0b
# rank                                             2
# artist_names                                   WOS
# artists_num                                    1.0
# ...                                            ...
# duration                                  183547.0
# country                                  Argentina
# region                               South America
# language                                   Spanish
# pivot                                            0
#
#                                                  2  \
# Unnamed: 0                                       2
# uri           spotify:track:2SJZdZ5DLtlRosJ2xHJJJa
# rank                                             3
# artist_names                          Paulo Londra
# artists_num                                    1.0
# ...                                            ...
# duration                                  204003.0
# country                                  Argentina
# region                               South America
# language                                   Spanish
# pivot                                            0
#
#                                                  3  \
# Unnamed: 0                                       3
# uri           spotify:track:1O2pcBJGej0pmH2Y9XZMs6
# rank                                             5
# artist_names                               Cris Mj
# artists_num                                    1.0
# ...                                            ...
# duration                                  153750.0
# country                                  Argentina
# region                               South America
# language                                   Spanish
# pivot                                            0
#
#                                                  4
# Unnamed: 0                                       4
# uri           spotify:track:1TpZKxGnHp37ohJRszTSiq
# rank                                             6
# artist_names                                Emilia
# artists_num                                    1.0
# ...                                            ...
# duration                                  133895.0
# country                                  Argentina
# region                               South America
# language                                   Spanish
# pivot                                            0
#
# [36 rows x 5 columns]

# %%
df_spotify_raw.dtypes
# Out:
# Unnamed: 0       int64
# uri             object
# rank            object
# artist_names    object
# artists_num     object
#                  ...
# duration        object
# country         object
# region          object
# language        object
# pivot           object
# Length: 36, dtype: object

# %% [markdown]
# ### 2. Cleaning Data

# %%
# Some rows have invalid values. Instead of a value they only have the name of the column as their value.
# Identify such values
non_numeric_values = df_spotify_raw[~df_spotify_raw['rank'].apply(lambda x: str(x).isdigit())]
print(non_numeric_values.head(5))


print('\nThis is the shape of wrong/blank entries:')
non_numeric_values.shape
# Out:
#         Unnamed: 0  uri  rank  artist_names  artists_num  artist_individual  \
# 29476        29476  uri  rank  artist_names  artists_num  artist_individual
# 51224        51224  uri  rank  artist_names  artists_num  artist_individual
# 75474        75474  uri  rank  artist_names  artists_num  artist_individual
# 81333        81333  uri  rank  artist_names  artists_num  artist_individual
# 104818      104818  uri  rank  artist_names  artists_num  artist_individual
#
#         artist_id  artist_genre  artist_img  collab  track_name  release_date  \
# 29476   artist_id  artist_genre  artist_img  collab  track_name  release_date
# 51224   artist_id  artist_genre  artist_img  collab  track_name  release_date
# 75474   artist_id  artist_genre  artist_img  collab  track_name  release_date
# 81333   artist_id  artist_genre  artist_img  collab  track_name  release_date
# 104818  artist_id  artist_genre  artist_img  collab  track_name  release_date
#
#         album_num_tracks  album_cover  source  ...  energy  key  mode  \
# 29476   album_num_tracks  album_cover  source  ...  energy  key  mode
# 51224   album_num_tracks  album_cover  source  ...  energy  key  mode
# 75474   album_num_tracks  album_cover  source  ...  energy  key  mode
# 81333   album_num_tracks  album_cover  source  ...  energy  key  mode
# 104818  album_num_tracks  album_cover  source  ...  energy  key  mode
#
#         loudness  speechiness  acousticness  instrumentalness  liveness  \
# 29476   loudness  speechiness  acousticness  instrumentalness  liveness
# 51224   loudness  speechiness  acousticness  instrumentalness  liveness
# 75474   loudness  speechiness  acousticness  instrumentalness  liveness
# 81333   loudness  speechiness  acousticness  instrumentalness  liveness
# 104818  loudness  speechiness  acousticness  instrumentalness  liveness
#
#         valence  tempo  duration  country  region  language  pivot
# 29476   valence  tempo  duration  country  region  language  pivot
# 51224   valence  tempo  duration  country  region  language  pivot
# 75474   valence  tempo  duration  country  region  language  pivot
# 81333   valence  tempo  duration  country  region  language  pivot
# 104818  valence  tempo  duration  country  region  language  pivot
#
# [5 rows x 36 columns]
#
# This is the shape of wrong/blank entries:
# (73, 36)

# %%
# remove Invalid rows 
df_spotify_clean_1 = df_spotify_raw.drop(non_numeric_values.index)

print('Shape comparison:')
print(df_spotify_raw.shape)
print(df_spotify_clean_1.shape)
# Out:
# Shape comparison:
# (1787999, 36)
# (1787926, 36)

# %%
# Remove useless columns
df_spotify_clean_2 = df_spotify_clean_1.drop(columns=['artist_img', 'album_cover','source','Unnamed: 0','release_date'])

# %%
# Find and remove NaN values


# show those "NaN" values
print(df_spotify_clean_2.isna().sum())
df_spotify_clean_3 = df_spotify_clean_2.copy()
df_spotify_clean_3 = df_spotify_clean_3.dropna(how = 'any')

# drop NaN values
print(' ')
print('Shape comparison')
print(df_spotify_clean_2.shape)
print(df_spotify_clean_3.shape)
# Out:
# uri                    0
# rank                   0
# artist_names           0
# artists_num            0
# artist_individual      0
#                     ...
# duration             395
# country                0
# region                 0
# language               0
# pivot                  0
# Length: 31, dtype: int64
#
# Shape comparison
# (1787926, 31)
# (1787531, 31)

# %% [markdown]
# ### 1.2 Correcting Data Types

# %%
df_spotify_clean_3.head(5)
# Out:
#                                     uri rank  artist_names artists_num  \
# 0  spotify:track:2gpQi3hbcUAcEG8m2dlgfB    1  Paulo Londra         1.0
# 1  spotify:track:2x8oBuYaObjqHqgGuIUZ0b    2           WOS         1.0
# 2  spotify:track:2SJZdZ5DLtlRosJ2xHJJJa    3  Paulo Londra         1.0
# 3  spotify:track:1O2pcBJGej0pmH2Y9XZMs6    5       Cris Mj         1.0
# 4  spotify:track:1TpZKxGnHp37ohJRszTSiq    6        Emilia         1.0
#
#   artist_individual                              artist_id       artist_genre  \
# 0      Paulo Londra  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z  argentine hip hop
# 1               WOS  spotify:artist:5YCc6xS5Gpj3EkaYGdjyNK    argentine indie
# 2      Paulo Londra  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z  argentine hip hop
# 3           Cris Mj  spotify:artist:1Yj5Xey7kTwvZla8sqdsdE     urbano chileno
# 4            Emilia  spotify:artist:0AqlFI0tz2DsEoJlKSIiT9      pop argentino
#
#   collab             track_name album_num_tracks peak_rank previous_rank  \
# 0      0                 Plan A              1.0         1             1
# 1      0           ARRANCARMELO              1.0         2           129
# 2      0                 Chance              2.0         3            59
# 3      0  Una Noche en Medellín              1.0         5             5
# 4      0          cuatro veinte              1.0         6             9
#
#   weeks_on_chart  streams        week  ...              energy   key mode  \
# 0              4  3003411  2022-04-14  ...  0.8340000000000001   0.0  1.0
# 1              2  2512175  2022-04-14  ...               0.354   5.0  1.0
# 2              2  2408983  2022-04-14  ...               0.463   1.0  0.0
# 3              8  2080139  2022-04-14  ...  0.5479999999999999  10.0  0.0
# 4              3  1923270  2022-04-14  ...               0.696   7.0  0.0
#
#              loudness speechiness        acousticness instrumentalness  \
# 0              -4.875      0.0444              0.0495              0.0
# 1              -7.358      0.0738  0.7240000000000001              0.0
# 2              -9.483      0.0646               0.241              0.0
# 3  -5.252999999999999       0.077              0.0924          4.6e-05
# 4              -3.817      0.0505              0.0811         6.25e-05
#
#   liveness              valence    tempo  duration    country         region  \
# 0   0.0658                0.557  173.935  178203.0  Argentina  South America
# 1    0.134                0.262   81.956  183547.0  Argentina  South America
# 2   0.0929  0.21600000000000005  137.915  204003.0  Argentina  South America
# 3   0.0534   0.8320000000000001   96.018  153750.0  Argentina  South America
# 4    0.101                0.501   95.066  133895.0  Argentina  South America
#
#   language pivot
# 0  Spanish     0
# 1  Spanish     0
# 2  Spanish     0
# 3  Spanish     0
# 4  Spanish     0
#
# [5 rows x 31 columns]

# %%
# Assign correct data types
df_spotify_clean_3['uri'] = df_spotify_clean_3['uri'].astype('str')
df_spotify_clean_3['rank'] = df_spotify_clean_3['rank'].astype('int')
df_spotify_clean_3['artist_names'] = df_spotify_clean_3['artist_names'].astype('str')
df_spotify_clean_3['artists_num'] = df_spotify_clean_3['artists_num'].astype('float')
df_spotify_clean_3['artist_individual'] = df_spotify_clean_3['artist_individual'].astype('str')
df_spotify_clean_3['artist_id'] = df_spotify_clean_3['artist_id'].astype('str')
df_spotify_clean_3['artist_genre'] = df_spotify_clean_3['artist_genre'].astype('str')
df_spotify_clean_3['collab'] = df_spotify_clean_3['collab'].astype('int')
df_spotify_clean_3['track_name'] = df_spotify_clean_3['track_name'].astype('str')
df_spotify_clean_3['album_num_tracks'] = df_spotify_clean_3['album_num_tracks'].astype('float')

df_spotify_clean_3['peak_rank'] = df_spotify_clean_3['peak_rank'].astype('int')
df_spotify_clean_3['previous_rank'] = df_spotify_clean_3['previous_rank'].astype('int')
df_spotify_clean_3['weeks_on_chart'] = df_spotify_clean_3['weeks_on_chart'].astype('int')
df_spotify_clean_3['streams'] = df_spotify_clean_3['streams'].astype('int')
df_spotify_clean_3['week'] = pd.to_datetime(df_spotify_clean_3['week'])
df_spotify_clean_3['danceability'] = df_spotify_clean_3['danceability'].astype('float')
df_spotify_clean_3['energy'] = df_spotify_clean_3['energy'].astype('float')
df_spotify_clean_3['key'] = df_spotify_clean_3['key'].astype('float')
df_spotify_clean_3['mode'] = df_spotify_clean_3['mode'].astype('float')
df_spotify_clean_3['loudness'] = df_spotify_clean_3['loudness'].astype('float')

df_spotify_clean_3['speechiness'] = df_spotify_clean_3['speechiness'].astype('float')
df_spotify_clean_3['acousticness'] = df_spotify_clean_3['acousticness'].astype('float')
df_spotify_clean_3['instrumentalness'] = df_spotify_clean_3['instrumentalness'].astype('float')
df_spotify_clean_3['liveness'] = df_spotify_clean_3['liveness'].astype('float')
df_spotify_clean_3['valence'] = df_spotify_clean_3['valence'].astype('float')
df_spotify_clean_3['tempo'] = df_spotify_clean_3['tempo'].astype('float')
df_spotify_clean_3['duration'] = df_spotify_clean_3['duration'].astype('float')
df_spotify_clean_3['country'] = df_spotify_clean_3['country'].astype('str')
df_spotify_clean_3['region'] = df_spotify_clean_3['region'].astype('str')
df_spotify_clean_3['language'] = df_spotify_clean_3['language'].astype('str')

df_spotify_clean_3['pivot'] = df_spotify_clean_3['pivot'].astype('int')

# %%
df_spotify_clean_3.dtypes
# Out:
# uri                   object
# rank                   int32
# artist_names          object
# artists_num          float64
# artist_individual     object
#                       ...
# duration             float64
# country               object
# region                object
# language              object
# pivot                  int32
# Length: 31, dtype: object

# %%
df_spotify_clean_3[df_spotify_clean_3['week']< '2017-01-01'].sample(n=40)

# During the analysis it was found out that the data from 2016 has faulty data. Specifically the 'weeks on chart' is always 1 which is impossible.
# Therefore the year 2016 cannot be used.
# Out:
#                                          uri  rank  \
# 612724  spotify:track:3zJw3rugfpVrmBeDDnUYzy    87
# 612774  spotify:track:2gbCG4Rt9984UZ7Tc0dIFd   142
# 612708  spotify:track:4dASQiO1Eoo3RJvt74FtXB    78
# 612807  spotify:track:2EEeOnHehOozLq4aS0n6SL   186
# 612746  spotify:track:3VTNVsTTu05dmTsVFrmGpK   110
# ...                                      ...   ...
# 612721  spotify:track:5uDASfU19gDxSjW8cnCaBp    86
# 612796  spotify:track:0v9Wz8o0BT8DU38R4ddjeH   168
# 612702  spotify:track:4tCtwWceOPWzenK2HAIJSb    69
# 577491  spotify:track:02WacdrRpm4zlP8H7X6bnQ   148
# 612748  spotify:track:4OZEu0Vwq0RB2LAq14v99n   112
#
#                                              artist_names  artists_num  \
# 612724                              John Lennon, Yoko Ono          4.0
# 612774                        Michael Bublé, Shania Twain          2.0
# 612708  Lil Wayne, Wiz Khalifa, Imagine Dragons, X Amb...          6.0
# 612807                                   KYLE, Lil Yachty          2.0
# 612746                         The Pogues, Kirsty MacColl          2.0
# ...                                                   ...          ...
# 612721                        Rob $tone, J. Davi$, Spooks          3.0
# 612796             Chance the Rapper, Lil Wayne, 2 Chainz          3.0
# 612702                       Fifth Harmony, Ty Dolla $ign          2.0
# 577491                                        Calum Scott          1.0
# 612748                         DJ Snake, Bipolar Sunshine          2.0
#
#                  artist_individual                              artist_id  \
# 612724  The Harlem Community Choir  spotify:artist:0vneleczrRRNPF1vj0x0vy
# 612774                Shania Twain  spotify:artist:5e4Dhzv426EvQe3aDb64jL
# 612708             Imagine Dragons  spotify:artist:53XhwfbYqKCa1cC15pYq2q
# 612807                        KYLE  spotify:artist:4qBgvVog0wzW75IQ48mU7v
# 612746                  The Pogues  spotify:artist:2wzMOQwNT6ZvVB4amvhFAH
# ...                            ...                                    ...
# 612721                    J. Davi$  spotify:artist:1rs3y69kDwkIdGJcOYngQt
# 612796           Chance the Rapper  spotify:artist:1anyVhU62p31KFi8MEzkbf
# 612702               Fifth Harmony  spotify:artist:1l8Fu6IkuTP0U5QetQJ5Xt
# 577491                 Calum Scott  spotify:artist:6ydoSd3N2mwgwBHtF6K7eX
# 612748                    DJ Snake  spotify:artist:540vIaP2JwjQb9dm3aArA4
#
#         artist_genre  collab  \
# 612724             0       1
# 612774  country dawn       1
# 612708   modern rock       1
# 612807       pop rap       1
# 612746        celtic       1
# ...              ...     ...
# 612721             0       1
# 612796           rap       1
# 612702    girl group       1
# 577491           pop       0
# 612748       pop rap       1
#
#                                                track_name  album_num_tracks  \
# 612724         Happy Xmas (War Is Over) - Remastered 2010              15.0
# 612774                White Christmas (with Shania Twain)              16.0
# 612708  Sucker for Pain (with Wiz Khalifa, Imagine Dra...               1.0
# 612807                            iSpy (feat. Lil Yachty)               1.0
# 612746       Fairytale of New York (feat. Kirsty MacColl)              19.0
# ...                                                   ...               ...
# 612721               Chill Bill (feat. J. Davi$ & Spooks)               1.0
# 612796            No Problem (feat. Lil Wayne & 2 Chainz)              14.0
# 612702               Work from Home (feat. Ty Dolla $ign)              12.0
# 577491                                  Dancing On My Own               1.0
# 612748                                             Middle              14.0
#
#         peak_rank  previous_rank  weeks_on_chart  streams       week  ...  \
# 612724         87             -1               1  4885251 2016-12-29  ...
# 612774        142             -1               1  3512996 2016-12-29  ...
# 612708         78             -1               1  5183750 2016-12-29  ...
# 612807        186             -1               1  2979074 2016-12-29  ...
# 612746        110             -1               1  4245077 2016-12-29  ...
# ...           ...            ...             ...      ...        ...  ...
# 612721         86             -1               1  4888031 2016-12-29  ...
# 612796        168             -1               1  3153421 2016-12-29  ...
# 612702         69             -1               1  5426035 2016-12-29  ...
# 577491        148             -1               1  3454666 2016-12-29  ...
# 612748        112             -1               1  4147726 2016-12-29  ...
#
#         energy   key  mode  loudness  speechiness  acousticness  \
# 612724   0.607   2.0   1.0   -11.076       0.0315        0.3180
# 612774   0.484  10.0   1.0    -7.588       0.0319        0.4690
# 612708   0.786   9.0   0.0    -4.378       0.3170        0.2550
# 612807   0.653   7.0   1.0    -6.745       0.2890        0.3780
# 612746   0.551   2.0   1.0    -7.480       0.0457        0.5820
# ...        ...   ...   ...       ...          ...           ...
# 612721   0.427   6.0   1.0   -10.028       0.1450        0.0312
# 612796   0.795  11.0   0.0    -5.192       0.1740        0.1560
# 612702   0.585   8.0   1.0    -5.861       0.0432        0.1030
# 577491   0.174   1.0   1.0    -8.796       0.0332        0.8510
# 612748   0.700   9.0   1.0    -5.331       0.0436        0.0199
#
#         instrumentalness  liveness  valence    tempo  duration  country  \
# 612724          0.000000    0.7650    0.395  146.537  213880.0   Global
# 612774          0.000012    0.1260    0.642   63.476  216627.0   Global
# 612708          0.000000    0.6500    0.739  169.021  243491.0   Global
# 612807          0.000000    0.2290    0.672   75.016  253107.0   Global
# 612746          0.000042    0.2560    0.428   78.111  272467.0   Global
# ...                  ...       ...      ...      ...       ...      ...
# 612721          0.000990    0.0906    0.230  108.034  177184.0   Global
# 612796          0.000000    0.1230    0.788  135.018  304607.0   Global
# 612702          0.000004    0.0644    0.593  105.017  214480.0   Global
# 577491          0.000019    0.0855    0.193  112.175  260004.0   Global
# 612748          0.000000    0.0549    0.213  104.981  220573.0   Global
#
#         region language pivot
# 612724  Global   Global     1
# 612774  Global   Global     1
# 612708  Global   Global     1
# 612807  Global   Global     0
# 612746  Global   Global     0
# ...        ...      ...   ...
# 612721  Global   Global     1
# 612796  Global   Global     0
# 612702  Global   Global     0
# 577491  Global   Global     0
# 612748  Global   Global     0
#
# [40 rows x 31 columns]

# %% [markdown]
# **Remove year 2016**

# %%
df_spotify_clean_3 = df_spotify_clean_3[df_spotify_clean_3['week'] >= '2017-01-01']

# %% [markdown]
# **Check genre 0**

# %%
df_spotify_clean_3[(df_spotify_clean_3['artist_genre'] == '0') & (df_spotify_clean_3['weeks_on_chart'] > 40 )& (df_spotify_clean_3['region'] == 'Global' ) ]
# Out:
#                                          uri  rank  \
# 596625  spotify:track:1lXQskY1Op1KzFG4GVcVpe   177
# 606240  spotify:track:02VBYrHfVwfEWXk5DXyf0T   188
# 608757  spotify:track:1LPSkqVhWVRUkKE03YUkpB   100
# 608798  spotify:track:4cG7HUWYHBV6R6tHn1gxrl   154
# 611603  spotify:track:02VBYrHfVwfEWXk5DXyf0T   197
# ...                                      ...   ...
# 663844  spotify:track:4cG7HUWYHBV6R6tHn1gxrl    68
# 663847  spotify:track:1LPSkqVhWVRUkKE03YUkpB    69
# 664063  spotify:track:1LPSkqVhWVRUkKE03YUkpB    99
# 664109  spotify:track:4cG7HUWYHBV6R6tHn1gxrl   156
# 667329  spotify:track:02VBYrHfVwfEWXk5DXyf0T    93
#
#                                             artist_names  artists_num  \
# 596625                              Natti Natasha, Ozuna          1.0
# 606240            Bruno Mars, Anderson .Paak, Silk Sonic          3.0
# 608757            Bruno Mars, Anderson .Paak, Silk Sonic          3.0
# 608798  Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine          4.0
# 611603            Bruno Mars, Anderson .Paak, Silk Sonic          3.0
# ...                                                  ...          ...
# 663844  Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine          4.0
# 663847            Bruno Mars, Anderson .Paak, Silk Sonic          3.0
# 664063            Bruno Mars, Anderson .Paak, Silk Sonic          3.0
# 664109  Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine          4.0
# 667329            Bruno Mars, Anderson .Paak, Silk Sonic          3.0
#
#          artist_individual                              artist_id  \
# 596625  Trío Los Josefinos  spotify:artist:67mFhErdTWmJ9slGMC6vOf
# 606240          Silk Sonic  spotify:artist:6PvvGcCY2XtUcSRld1Wilr
# 608757          Silk Sonic  spotify:artist:6PvvGcCY2XtUcSRld1Wilr
# 608798            Dopamine  spotify:artist:3Edve4VIATi0OZngclQlkN
# 611603          Silk Sonic  spotify:artist:6PvvGcCY2XtUcSRld1Wilr
# ...                    ...                                    ...
# 663844            Dopamine  spotify:artist:3Edve4VIATi0OZngclQlkN
# 663847          Silk Sonic  spotify:artist:6PvvGcCY2XtUcSRld1Wilr
# 664063          Silk Sonic  spotify:artist:6PvvGcCY2XtUcSRld1Wilr
# 664109            Dopamine  spotify:artist:3Edve4VIATi0OZngclQlkN
# 667329          Silk Sonic  spotify:artist:6PvvGcCY2XtUcSRld1Wilr
#
#        artist_genre  collab  \
# 596625            0       0
# 606240            0       1
# 608757            0       1
# 608798            0       1
# 611603            0       1
# ...             ...     ...
# 663844            0       1
# 663847            0       1
# 664063            0       1
# 664109            0       1
# 667329            0       1
#
#                                                track_name  album_num_tracks  \
# 596625                                           Criminal              16.0
# 606240                                Leave The Door Open              10.0
# 608757                                Leave The Door Open               9.0
# 608798  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...               1.0
# 611603                                Leave The Door Open              10.0
# ...                                                   ...               ...
# 663844  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...               1.0
# 663847                                Leave The Door Open               9.0
# 664063                                Leave The Door Open               9.0
# 664109  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...               1.0
# 667329                                Leave The Door Open              10.0
#
#         peak_rank  previous_rank  weeks_on_chart  streams       week  ...  \
# 596625         21            182              46  3856488 2018-08-02  ...
# 606240          5            143              55  5487002 2022-03-24  ...
# 608757          5             99              46  6940029 2022-01-20  ...
# 608798         15            156              48  5712313 2022-01-20  ...
# 611603          5            188              56  5391575 2022-03-31  ...
# ...           ...            ...             ...      ...        ...  ...
# 663844         15            194              46  8046772 2022-01-06  ...
# 663847          5            110              44  7987911 2022-01-06  ...
# 664063          5             69              45  7181617 2022-01-13  ...
# 664109         15             68              47  5741857 2022-01-13  ...
# 667329          5             87              59  6896730 2022-04-21  ...
#
#         energy  key  mode  loudness  speechiness  acousticness  \
# 596625   0.794  2.0   0.0    -3.821       0.0689        0.0416
# 606240   0.616  5.0   1.0    -7.964       0.0324        0.1820
# 608757   0.616  5.0   1.0    -7.964       0.0324        0.1820
# 608798   0.862  2.0   1.0    -3.424       0.1260        0.0076
# 611603   0.616  5.0   1.0    -7.964       0.0324        0.1820
# ...        ...  ...   ...       ...          ...           ...
# 663844   0.862  2.0   1.0    -3.424       0.1260        0.0076
# 663847   0.616  5.0   1.0    -7.964       0.0324        0.1820
# 664063   0.616  5.0   1.0    -7.964       0.0324        0.1820
# 664109   0.862  2.0   1.0    -3.424       0.1260        0.0076
# 667329   0.616  5.0   1.0    -7.964       0.0324        0.1820
#
#         instrumentalness  liveness  valence    tempo  duration  country  \
# 596625          0.000060    0.1390    0.837   79.983  232699.0   Global
# 606240          0.000000    0.0927    0.719  148.088  242096.0   Global
# 608757          0.000000    0.0927    0.719  148.088  242096.0   Global
# 608798          0.000132    0.3030    0.801  122.980  169153.0   Global
# 611603          0.000000    0.0927    0.719  148.088  242096.0   Global
# ...                  ...       ...      ...      ...       ...      ...
# 663844          0.000132    0.3030    0.801  122.980  169153.0   Global
# 663847          0.000000    0.0927    0.719  148.088  242096.0   Global
# 664063          0.000000    0.0927    0.719  148.088  242096.0   Global
# 664109          0.000132    0.3030    0.801  122.980  169153.0   Global
# 667329          0.000000    0.0927    0.719  148.088  242096.0   Global
#
#         region language pivot
# 596625  Global   Global     0
# 606240  Global   Global     1
# 608757  Global   Global     1
# 608798  Global   Global     1
# 611603  Global   Global     1
# ...        ...      ...   ...
# 663844  Global   Global     1
# 663847  Global   Global     1
# 664063  Global   Global     1
# 664109  Global   Global     1
# 667329  Global   Global     1
#
# [36 rows x 31 columns]

# %%
# Clean genres
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'Ke Personajes', 'artist_genre'] = 'cumbia'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'Vang, Cloud 5', 'artist_genre'] = 'chill pop'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'Lu, Willistic, datfitzx', 'artist_genre'] = 'r&b'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'RYH', 'artist_genre'] = 'cumbia'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'Orinn, Huy Vạc', 'artist_genre'] = 'sad lo-fi'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'La T y La M', 'artist_genre'] = 'cumbia'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'BoyWithUke', 'artist_genre'] = 'bedroom pop'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'Kai Đinh, SIVAN', 'artist_genre'] = 'r&b'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'Macklemore & Ryan Lewis, Macklemore, Ryan Lewis, Ray Dalton', 'artist_genre'] = 'hip hop'
df_spotify_clean_3.loc[df_spotify_clean_3['artist_names'] == 'HIEUTHUHAI, Harmonie', 'artist_genre'] = 'rap'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:5stPVcRqb4qixbafP9e8lt', 'artist_genre'] = 'reggaeton'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:5ZzNGwBBGaewMGG1LucGfp', 'artist_genre'] = 'trap latino'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:57Ba26w9eoXx8BBUNgRNLV', 'artist_genre'] = 'reggaeton'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:2UypFzxfaYgMUnQX2k4qtj', 'artist_genre'] = 'latin'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:13Rf6RaZT13TW4xLQR3MQr', 'artist_genre'] = 'rap'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:2q9udNV9NK0BL3q9p6TLxf', 'artist_genre'] = 'tropical'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:2rzZ0IGxgrGUAPwrWn80z7', 'artist_genre'] = 'pop'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:02VBYrHfVwfEWXk5DXyf0T', 'artist_genre'] = 'soul'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:1LPSkqVhWVRUkKE03YUkpB', 'artist_genre'] = 'soul'
df_spotify_clean_3.loc[df_spotify_clean_3['uri'] == 'spotify:track:4cG7HUWYHBV6R6tHn1gxrl', 'artist_genre'] = 'dance pop'

# %%
df_spotify_clean_3[df_spotify_clean_3['artist_genre'] == '0']
# Out:
#                                           uri  rank           artist_names  \
# 518      spotify:track:7GcN9q4AAH4uzQKvyuvByT   179               LA YOUNG
# 1906     spotify:track:7CAdT0HdiQNlt1C7xk2hep   145              Jung Kook
# 2313     spotify:track:4jl44FUrq3Mrexi05J7K7h   116           FUTURE BEATS
# 2863     spotify:track:4jl44FUrq3Mrexi05J7K7h    89           FUTURE BEATS
# 5281     spotify:track:7GcN9q4AAH4uzQKvyuvByT   180               LA YOUNG
# ...                                       ...   ...                    ...
# 1787959  spotify:track:2MHGIiWus5xHykiZGuDtNe   158              Sean, Lửa
# 1787960  spotify:track:2MHGIiWus5xHykiZGuDtNe   158              Sean, Lửa
# 1787967  spotify:track:1Uj89dqT3gdnnKZnaOMWI8   166    TIA, fueled by boba
# 1787983  spotify:track:1c0LbgYt51JeBUMAzofjkq   183    TGSN, tlinh, RZ Mas
# 1787985  spotify:track:4HlHNLtfxP7Y5z03j3eNOi   184  Sơn Tùng M-TP, Onionn
#
#          artists_num artist_individual                              artist_id  \
# 518              1.0          LA YOUNG  spotify:artist:2Xi0zO1N71Ff9KymMs93YX
# 1906             1.0         Jung Kook  spotify:artist:6HaGTQPmzraVmaVxvz6EUc
# 2313             1.0      FUTURE BEATS  spotify:artist:6Y6LEiyvXx2tTKggz1jF5q
# 2863             1.0      FUTURE BEATS  spotify:artist:6Y6LEiyvXx2tTKggz1jF5q
# 5281             1.0          LA YOUNG  spotify:artist:2Xi0zO1N71Ff9KymMs93YX
# ...              ...               ...                                    ...
# 1787959          2.0              Sean  spotify:artist:1xNqmjTeWon7iX8kbPKpZz
# 1787960          2.0               Lửa  spotify:artist:4HOm37irsRwVEddNx6d0lq
# 1787967          2.0    fueled by boba  spotify:artist:4NKeJPVrlhASY3FXkQsLGn
# 1787983          3.0            RZ Mas  spotify:artist:39UJlviUwzZGZrA8DiQy31
# 1787985          2.0            Onionn  spotify:artist:25M5YMbLCbYDSFPhQXYE8c
#
#         artist_genre  collab                      track_name  \
# 518                0       0                  Como Estrellas
# 1906               0       0  Stay Alive (Prod. SUGA of BTS)
# 2313               0       0      CHOCOPOP RKT - TURREO EDIT
# 2863               0       0      CHOCOPOP RKT - TURREO EDIT
# 5281               0       0                  Como Estrellas
# ...              ...     ...                             ...
# 1787959            0       1                        Em Thích
# 1787960            0       1                        Em Thích
# 1787967            0       1                     in the dark
# 1787983            0       1                           Siren
# 1787985            0       1                    CHẠY NGAY ĐI
#
#          album_num_tracks  peak_rank  previous_rank  weeks_on_chart  streams  \
# 518                   1.0        179            180               2   189716
# 1906                  1.0        145             -1               1   279533
# 2313                  1.0        116             -1               1   321900
# 2863                  1.0         89            116               2   444167
# 5281                  1.0        180             -1               1   180772
# ...                   ...        ...            ...             ...      ...
# 1787959               2.0         65            152              20    44740
# 1787960               2.0         65            152              20    44740
# 1787967               2.0        156            172               5    43084
# 1787983               1.0         31            187              17    39591
# 1787985               1.0          1             -1              60    39561
#
#               week  ...  energy   key  mode  loudness  speechiness  \
# 518     2021-04-22  ...   0.495   6.0   1.0    -6.058       0.1100
# 1906    2022-02-17  ...   0.760   2.0   0.0    -5.889       0.0682
# 2313    2022-05-19  ...   0.754   2.0   1.0    -2.040       0.2920
# 2863    2022-05-26  ...   0.754   2.0   1.0    -2.040       0.2920
# 5281    2021-04-15  ...   0.495   6.0   1.0    -6.058       0.1100
# ...            ...  ...     ...   ...   ...       ...          ...
# 1787959 2022-05-05  ...   0.330   9.0   1.0   -12.065       0.2260
# 1787960 2022-05-05  ...   0.330   9.0   1.0   -12.065       0.2260
# 1787967 2022-05-05  ...   0.382   9.0   0.0    -9.915       0.0505
# 1787983 2022-05-05  ...   0.732  11.0   0.0    -6.092       0.1150
# 1787985 2022-05-05  ...   0.806   2.0   0.0    -3.824       0.0504
#
#          acousticness  instrumentalness  liveness  valence    tempo  duration  \
# 518             0.764          0.000000    0.2610    0.752  170.044  219000.0
# 1906            0.299          0.000000    0.1030    0.495  130.096  210928.0
# 2313            0.191          0.000000    0.1640    0.622  180.082  136046.0
# 2863            0.191          0.000000    0.1640    0.622  180.082  136046.0
# 5281            0.764          0.000000    0.2610    0.752  170.044  219000.0
# ...               ...               ...       ...      ...      ...       ...
# 1787959         0.688          0.000000    0.1110    0.156  175.423  176151.0
# 1787960         0.688          0.000000    0.1110    0.156  175.423  176151.0
# 1787967         0.422          0.000254    0.1180    0.209  179.799  194578.0
# 1787983         0.548          0.000001    0.2580    0.777  130.001  157067.0
# 1787985         0.423          0.000000    0.0883    0.453  127.020  272508.0
#
#            country         region    language pivot
# 518      Argentina  South America     Spanish     0
# 1906     Argentina  South America     Spanish     0
# 2313     Argentina  South America     Spanish     0
# 2863     Argentina  South America     Spanish     0
# 5281     Argentina  South America     Spanish     0
# ...            ...            ...         ...   ...
# 1787959    Vietnam           Asia  Vietnamese     0
# 1787960    Vietnam           Asia  Vietnamese     1
# 1787967    Vietnam           Asia  Vietnamese     1
# 1787983    Vietnam           Asia  Vietnamese     1
# 1787985    Vietnam           Asia  Vietnamese     1
#
# [104543 rows x 31 columns]

# %% [markdown]
# ### 2. Basic Descriptive Analysis

# %%
df_spotify_clean_3.describe().T
# Out:
#                       count           mean      min       25%       50%  \
# rank              1787213.0      99.072611      1.0      49.0      98.0
# artists_num       1787213.0       2.244509      1.0       1.0       2.0
# collab            1787213.0       0.627659      0.0       0.0       1.0
# album_num_tracks  1787213.0       8.465175      1.0       1.0       7.0
# peak_rank         1787213.0      40.064027      1.0       5.0      21.0
# ...                     ...            ...      ...       ...       ...
# liveness          1787213.0       0.169375   0.0134    0.0922     0.118
# valence           1787213.0       0.553048  0.00001     0.391     0.558
# tempo             1787213.0     121.992354   31.262    96.699   119.932
# duration          1787213.0  211536.174058  30133.0  173948.0  202735.0
# pivot             1787213.0       0.379384      0.0       0.0       0.0
#
#                        75%        max           std
# rank                 149.0      200.0     57.740651
# artists_num            3.0       20.0      1.610716
# collab                 1.0        1.0      0.483429
# album_num_tracks      14.0      199.0      8.550258
# peak_rank             61.0      200.0     45.608224
# ...                    ...        ...           ...
# liveness             0.209       0.99      0.126491
# valence              0.729      0.992      0.222453
# tempo              141.026    232.018     30.165851
# duration          234000.0  1787030.0  58058.277548
# pivot                  1.0        1.0      0.485234
#
# [22 rows x 8 columns]

# %% [markdown]
# ###

# %% [markdown]
# **Delete extra columns**

# %%
df_spotify_clean_3.drop(['pivot','speechiness', 'rank', 'previous_rank'], axis=1, inplace=True)

# %% [markdown]
# **Round miliseconds to seconds**

# %%
df_spotify_clean_3['duration'] = (df_spotify_clean_3['duration']/1000).round()

# %% [markdown]
# **Separate Global and not global entries**

# %%
df_spotify_clean_global = df_spotify_clean_3[df_spotify_clean_3['country'] == 'Global']

df_spotify_clean_no_global = df_spotify_clean_3[df_spotify_clean_3['country'] != 'Global']

df_spotify_clean_no_global.sample(n=7)
# Out:
#                                           uri  \
# 1333096  spotify:track:7umEhzfURpGTSRbcX84qLy
# 1221364  spotify:track:5mNOfozRJBZGnq4gO4rwM2
# 771273   spotify:track:3Kdlue3eVr9jf0Ns5wNPMj
# 285669   spotify:track:2K1CQMoG2Dy5nmeOYnhoi8
# 1249376  spotify:track:6b2HYgqcK9mvktt4GxAu72
# 1125552  spotify:track:4LaGu95Ui2s4vprSQYWUAZ
# 1640954  spotify:track:2jyjhRf6DVbMPU5zxagN2h
#
#                                               artist_names  artists_num  \
# 1333096                                       Young Leosia          1.0
# 1221364                Gur Sidhu, Jasmine Sandlas, Kaptaan          3.0
# 771273                                    Jer 柳應廷, 香港兒童合唱團          2.0
# 285669   J Balvin, KAROL G, Nicky Jam, Crissin, Totoy E...          6.0
# 1249376             Justin Quiles, Chimbala, Zion & Lennox          3.0
# 1125552                      Pop Smoke, 21 Savage, 42 Dugg          3.0
# 1640954                                          Passenger          1.0
#
#         artist_individual                              artist_id  \
# 1333096      Young Leosia  spotify:artist:0iBTVnJ1Sff92zCDujfvyJ
# 1221364           Kaptaan  spotify:artist:0F4kRjMBP6NrjpEBEoL0Xb
# 771273            香港兒童合唱團  spotify:artist:20GdoyuHyDOzJe7T2EcFqI
# 285669    Natan & Shander  spotify:artist:5OBK3iQwjNQqElPmn4TgAE
# 1249376     Justin Quiles  spotify:artist:14zUHaJZo1mnYtn6IBRaRP
# 1125552         21 Savage  spotify:artist:1URnnhqYAYcrqrcwql10ft
# 1640954         Passenger  spotify:artist:0gadJ2b9A4SKsB1RFkBb66
#
#                  artist_genre  collab  \
# 1333096            polish pop       0
# 1221364                     0       1
# 771273                      0       1
# 285669   reggaeton colombiano       1
# 1249376             reggaeton       1
# 1125552               hip hop       1
# 1640954            neo mellow       0
#
#                                          track_name  album_num_tracks  \
# 1333096                                    Szklanki               1.0
# 1221364                                   Bamb Agya               1.0
# 771273                        神奇之路 (電影《媽媽的神奇小子》主題曲)               1.0
# 285669                              Poblado - Remix              24.0
# 1249376                                        Loco              14.0
# 1125552  Bout A Million (feat. 42 Dugg & 21 Savage)              20.0
# 1640954                                  Let Her Go              12.0
#
#          peak_rank  weeks_on_chart  streams       week  danceability  energy  \
# 1333096          1               6   783987 2021-03-11         0.953   0.595
# 1221364        116               5    18151 2022-07-07         0.823   0.709
# 771273          42               1    69180 2021-08-12         0.414   0.372
# 285669          11              41    28598 2022-03-31         0.813   0.810
# 1249376         37              34    16285 2022-01-27         0.771   0.885
# 1125552         64               1   314505 2021-07-22         0.716   0.670
# 1640954        117              32     8370 2021-02-18         0.509   0.538
#
#          key  mode  loudness  acousticness  instrumentalness  liveness  \
# 1333096  0.0   1.0    -8.010        0.2350          0.000000    0.0679
# 1221364  1.0   1.0    -3.937        0.0235          0.000000    0.0834
# 771273   4.0   1.0    -9.048        0.8410          0.000000    0.1470
# 285669   3.0   0.0    -5.382        0.1120          0.000002    0.3770
# 1249376  8.0   1.0    -3.660        0.2220          0.000000    0.0918
# 1125552  0.0   0.0    -6.995        0.5260          0.000000    0.1300
# 1640954  7.0   1.0    -7.335        0.3850          0.000000    0.1040
#
#          valence    tempo  duration               country           region  \
# 1333096    0.675  124.965     163.0                Poland           Europe
# 1221364    0.499   93.012     200.0              Pakistan             Asia
# 771273     0.188   79.866     333.0             Hong Kong             Asia
# 285669     0.632   93.005     393.0            Costa Rica  Central America
# 1249376    0.826  128.031     232.0                Panama  Central America
# 1125552    0.411  145.043     204.0           Netherlands           Europe
# 1640954    0.244   75.089     253.0  United Arab Emirates      Middle East
#
#           language
# 1333096     Polish
# 1221364       Urdu
# 771273   Cantonese
# 285669     Spanish
# 1249376    Spanish
# 1125552      Dutch
# 1640954     Arabic

# %%
df_spotify_clean_3.sample(n=10)
# Out:
#                                           uri  \
# 456585   spotify:track:6K5BsR04ijf3FHNzjbaagD
# 565431   spotify:track:3iw6V4LH7yPj1ESORX9RIN
# 1295092  spotify:track:4gvrJnKCKIPiacNsWVQwEU
# 638935   spotify:track:7E1jVNoWuemqUryI4FxsVD
# 1450689  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 1170896  spotify:track:1s59X35jDULAyOGmBuTAnd
# 1694252  spotify:track:53bbEINuw0ez3ntLcqYCu2
# 1782591  spotify:track:4iDyFW4a7iCJh2VqSpwGQz
# 1517360  spotify:track:13XxxfnZmFEkU90QN8bOjz
# 321704   spotify:track:7JYa8V4dGXSDcZnO2CiRaP
#
#                                               artist_names  artists_num  \
# 456585          Myke Towers, Farruko, Arcangel, Sech, Zion          5.0
# 565431                   Nathan Evans, 220 KID, Billen Ted          3.0
# 1295092                                CKay, Dj Yo!, AX'EL          3.0
# 638935                           Ariana Grande, The Weeknd          2.0
# 1450689  Carolina Gaitán - La Gaita, Mauro Castillo, Ad...          7.0
# 1170896                         Lenin Ramírez, Grupo Firme          2.0
# 1694252                                       SLAVA MARLOW          1.0
# 1782591                                 TIA, Le Thien Hieu          2.0
# 1517360                                   C.R.O, Duki, FMK          3.0
# 321704                                 Leaderbrain, Beyond          2.0
#
#         artist_individual                              artist_id  \
# 456585            Farruko  spotify:artist:329e4yvIujISKGKz1BZZbO
# 565431         Billen Ted  spotify:artist:5PoZtBo8xZKqPWlZrIDq82
# 1295092              CKay  spotify:artist:048LktY5zMnakWq7PTtFrz
# 638935      Ariana Grande  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR
# 1450689      Rhenzy Feliz  spotify:artist:2as15AH2BTrPk8v4gyElmr
# 1170896     Lenin Ramírez  spotify:artist:3hTffafUYLLgO4yuPAxb5U
# 1694252      SLAVA MARLOW  spotify:artist:55jryyk7RhvMbrvoF0ndBh
# 1782591               TIA  spotify:artist:6LrBtADUmDoLlcTrg448Qt
# 1517360             C.R.O  spotify:artist:4puAp107dCehraE47QXVQX
# 321704             Beyond  spotify:artist:7KcIok6StqYSedgtjmtsqP
#
#                   artist_genre  collab  \
# 456585               reggaeton       1
# 565431                       0       1
# 1295092               afro r&b       1
# 638935                     pop       1
# 1450689                      0       1
# 1170896  nueva musica mexicana       1
# 1694252        russian hip hop       0
# 1782591                  v-pop       1
# 1517360            trap triste       1
# 321704                       0       1
#
#                                                 track_name  album_num_tracks  \
# 456585                                    Si Se Da - Remix               1.0
# 565431   Wellerman - Sea Shanty / 220 KID x Billen Ted ...               1.0
# 1295092       love nwantiti (feat. Dj Yo! & AX'EL) - Remix               1.0
# 638935                     off the table (with The Weeknd)              14.0
# 1450689                          We Don't Talk About Bruno              44.0
# 1170896                  Yo Ya No Vuelvo Contigo - En Vivo               1.0
# 1694252                                          По Глазам               5.0
# 1782591                                       Ai Đưa Em Về               1.0
# 1517360                                       INTERESTELAR               1.0
# 321704                                                LOCA               1.0
#
#          peak_rank  weeks_on_chart  streams       week  danceability  energy  \
# 456585          18             112    17639 2021-09-23         0.817   0.672
# 565431           2              54   403775 2022-02-24         0.722   0.893
# 1295092         12              23   137359 2022-02-24         0.579   0.596
# 638935          20               3  5308945 2020-11-19         0.411   0.522
# 1450689         12              13    78223 2022-03-24         0.577   0.450
# 1170896        140              10     6846 2021-05-13         0.643   0.350
# 1694252          1              18    51248 2021-02-25         0.551   0.632
# 1782591         69              81    55245 2021-04-29         0.809   0.490
# 1517360         73               4   294636 2022-02-24         0.831   0.628
# 321704          82               5     4794 2022-01-20         0.722   0.719
#
#           key  mode  loudness  acousticness  instrumentalness  liveness  \
# 456585   11.0   0.0    -5.612        0.4410          0.000000    0.1300
# 565431    0.0   0.0    -3.255        0.0441          0.000937    0.0673
# 1295092   8.0   1.0    -4.823        0.4360          0.093800    0.0549
# 638935    0.0   1.0    -7.295        0.5190          0.000000    0.3980
# 1450689   0.0   0.0    -8.516        0.3570          0.000000    0.1110
# 1170896   4.0   0.0    -5.924        0.7840          0.000000    0.1020
# 1694252   8.0   0.0    -5.873        0.1500          0.011300    0.5590
# 1782591  10.0   0.0    -7.080        0.8390          0.000000    0.1170
# 1517360   4.0   0.0    -4.353        0.0775          0.000000    0.0905
# 321704    6.0   1.0    -8.891        0.5770          0.001790    0.1730
#
#          valence    tempo  duration      country           region    language
# 456585     0.774   93.999     332.0  El Salvador  Central America     Spanish
# 565431     0.439  119.932     117.0      Germany           Europe      German
# 1295092    0.443  119.900     188.0         Peru    South America     Spanish
# 638935     0.382   88.332     240.0       Global           Global      Global
# 1450689    0.830  205.863     216.0    Singapore             Asia     English
# 1170896    0.541  118.199     240.0    Nicaragua  Central America     Spanish
# 1694252    0.333   75.905     120.0      Ukraine           Europe   Ukrainian
# 1782591    0.353   99.967     233.0      Vietnam             Asia  Vietnamese
# 1517360    0.467   90.006     173.0        Spain           Europe     Spanish
# 321704     0.419  104.982     164.0       Cyprus           Europe       Greek

# %%
df_spotify_clean_global.sample(n=10)
# Out:
#                                          uri  \
# 646885  spotify:track:07MDkzWARZaLEdKxo6yArG
# 664058  spotify:track:0G2zPzWqVjR68iNPmx2TBe
# 618662  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 582575  spotify:track:2NMjggapJcXXM7WccGEBUO
# 630613  spotify:track:4cG7HUWYHBV6R6tHn1gxrl
# 615698  spotify:track:17Fd6Yb7mSbinKG8LoWfFl
# 660716  spotify:track:6vN77lE9LK6HP2DewaN6HZ
# 615969  spotify:track:7DM4BPaS7uofFul3ywMe46
# 641064  spotify:track:7DcvwMAiqKJQD1rrdfxSDx
# 659754  spotify:track:5R9KPXQVeyqsHZoPLMgfNy
#
#                                             artist_names  artists_num  \
# 646885                   THE ANXIETY, WILLOW, Tyler Cole          3.0
# 664058                             Mora, Bad Bunny, Sech          3.0
# 618662                                   Shakira, Maluma          2.0
# 582575                                         Bad Bunny          1.0
# 630613  Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine          4.0
# 615698                                 Mike Posner, Seeb          2.0
# 660716                                   Lil Baby, Drake          2.0
# 615969                              Ricky Martin, Maluma          2.0
# 641064                 Young Thug, J. Cole, Travis Scott          3.0
# 659754                       Matheus Fernandes, Dilsinho          2.0
#
#        artist_individual                              artist_id  \
# 646885            WILLOW  spotify:artist:3rWZHrfrsPBxVy692yAIxF
# 664058              Sech  spotify:artist:77ziqFxp5gaInVrF2lj4ht
# 618662           Shakira  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 582575         Bad Bunny  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 630613  Mufasa & Hypeman  spotify:artist:4L2dV3zY7RmkeiNO035Fi0
# 615698       Mike Posner  spotify:artist:2KsP6tYLJlTBvSUxnwlVWa
# 660716             Drake  spotify:artist:3TVXtAsR1Inumwj472S9r4
# 615969      Ricky Martin  spotify:artist:7slfeZO9LsJbWgpkIoXBUJ
# 641064      Travis Scott  spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY
# 659754          Dilsinho  spotify:artist:4NUePmzDvCYqilXBFa91Hg
#
#           artist_genre  collab  \
# 646885       dance pop       1
# 664058  panamanian pop       1
# 618662           latin       1
# 582575           latin       0
# 630613       dance pop       1
# 615698             edm       1
# 660716         hip hop       1
# 615969           latin       1
# 641064         hip hop       1
# 659754     pagode novo       1
#
#                                                track_name  album_num_tracks  \
# 646885                                Meet Me At Our Spot              10.0
# 664058                                    Volando - Remix               1.0
# 618662                            Chantaje (feat. Maluma)              13.0
# 582575                                  Enséñame a Bailar              23.0
# 630613  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...               1.0
# 615698                I Took A Pill In Ibiza - Seeb Remix              18.0
# 660716                                         Yes Indeed              17.0
# 615969                        Vente Pa' Ca (feat. Maluma)               1.0
# 641064          The London (feat. J. Cole & Travis Scott)               1.0
# 659754                                     Baby Me Atende               1.0
#
#         peak_rank  weeks_on_chart   streams       week  danceability  energy  \
# 646885         24               8  14407480 2021-10-28         0.773   0.470
# 664058         19              27   7329506 2022-01-13         0.659   0.688
# 618662         13              34   4454522 2017-08-17         0.852   0.773
# 582575         27               3   9872149 2022-05-26         0.810   0.789
# 630613         15              21  15479076 2021-07-15         0.824   0.862
# 615698         40               5   5548546 2017-01-26         0.663   0.713
# 660716         12              20   7549538 2018-09-27         0.963   0.346
# 615969         49              13   4908644 2017-03-23         0.663   0.920
# 641064          6               1  22075360 2019-05-30         0.796   0.586
# 659754        172               1   5380533 2021-06-17         0.650   0.792
#
#          key  mode  loudness  acousticness  instrumentalness  liveness  \
# 646885   2.0   1.0    -7.930       0.01530          0.000193    0.0851
# 664058   6.0   1.0    -4.649       0.20700          0.000000    0.1130
# 618662   8.0   0.0    -2.921       0.18700          0.000030    0.1590
# 582575   8.0   1.0    -5.080       0.19100          0.000011    0.4670
# 630613   2.0   1.0    -3.424       0.00760          0.000132    0.3030
# 615698   7.0   0.0    -6.647       0.03530          0.000008    0.0843
# 660716   5.0   0.0    -9.309       0.03550          0.000000    0.1080
# 615969  11.0   0.0    -4.070       0.00431          0.000017    0.1010
# 641064   4.0   0.0    -6.946       0.02470          0.000000    0.1320
# 659754   6.0   0.0    -3.825       0.60700          0.000024    0.9200
#
#         valence    tempo  duration country  region language
# 646885    0.399   94.995     163.0  Global  Global   Global
# 664058    0.632  153.979     273.0  Global  Global   Global
# 618662    0.907  102.034     196.0  Global  Global   Global
# 582575    0.770  105.009     176.0  Global  Global   Global
# 630613    0.801  122.980     169.0  Global  Global   Global
# 615698    0.690  101.965     198.0  Global  Global   Global
# 660716    0.562  119.957     142.0  Global  Global   Global
# 615969    0.533   99.935     259.0  Global  Global   Global
# 641064    0.179   97.981     200.0  Global  Global   Global
# 659754    0.872  154.027     226.0  Global  Global   Global

# %% [markdown]
# ### 3. Exporting Data

# %%
df_spotify_clean_no_global.to_pickle(os.path.join(data_path, '02 Data', 'Prepared Data', 'spotify_clean_no_global.pkl'))

df_spotify_clean_global.to_pickle(os.path.join(data_path, '02 Data', 'Prepared Data', 'spotify_clean_global.pkl'))

# %%
df_spotify_clean_no_global.to_csv(os.path.join(data_path, '02 Data', 'Prepared Data', 'spotify_clean_no_global.csv'))

df_spotify_clean_global.to_csv(os.path.join(data_path, '02 Data', 'Prepared Data', 'spotify_clean_global.csv'))

# %%
df_spotify_clean_global.head()
# Out:
#                                          uri         artist_names  \
# 573718  spotify:track:6MWtB6iiXyIwun0YzU6DFP          Post Malone
# 573719  spotify:track:2rPE9A1vEgShuZxxzR2tZH        Ariana Grande
# 573720  spotify:track:5p7ujcrUXASCNwRaWNHR1C               Halsey
# 573721  spotify:track:25sgk305KZfyuqVBQIahim              Ava Max
# 573722  spotify:track:1rqqCSm0Qe4I9rUvWncaom  Panic! At The Disco
#
#         artists_num    artist_individual  \
# 573718          1.0          Post Malone
# 573719          1.0        Ariana Grande
# 573720          1.0               Halsey
# 573721          1.0              Ava Max
# 573722          1.0  Panic! At The Disco
#
#                                     artist_id artist_genre  collab  \
# 573718  spotify:artist:246dkjvS1zLTtiykXe5h60          rap       0
# 573719  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR          pop       0
# 573720  spotify:artist:26VFTg2z8YR0cCuwLzESi2   electropop       0
# 573721  spotify:artist:4npEfmQ6YuiwW1GpUmaq3F          pop       0
# 573722  spotify:artist:20JZFwl6HVl6yg8a4H3ZqK  modern rock       0
#
#               track_name  album_num_tracks  peak_rank  weeks_on_chart  \
# 573718              Wow.               1.0          2               4
# 573719     thank u, next               1.0          1              11
# 573720        Without Me               1.0          4              15
# 573721  Sweet but Psycho               1.0          6              16
# 573722        High Hopes              11.0          9              30
#
#          streams       week  danceability  energy   key  mode  loudness  \
# 573718  29944242 2019-01-17         0.833   0.539  11.0   0.0    -7.399
# 573719  27807232 2019-01-17         0.724   0.647   1.0   1.0    -5.642
# 573720  27138512 2019-01-17         0.752   0.488   6.0   1.0    -7.050
# 573721  22400542 2019-01-17         0.719   0.704   1.0   1.0    -4.724
# 573722  19643546 2019-01-17         0.579   0.904   5.0   1.0    -2.729
#
#         acousticness  instrumentalness  liveness  valence    tempo  duration  \
# 573718        0.1630          0.000002    0.1010    0.385   99.947     150.0
# 573719        0.2800          0.000000    0.1020    0.435  106.960     207.0
# 573720        0.2970          0.000009    0.0936    0.533  136.041     202.0
# 573721        0.0691          0.000000    0.1660    0.628  133.002     187.0
# 573722        0.1930          0.000000    0.0640    0.681   82.014     191.0
#
#        country  region language
# 573718  Global  Global   Global
# 573719  Global  Global   Global
# 573720  Global  Global   Global
# 573721  Global  Global   Global
# 573722  Global  Global   Global

# %%
df_spotify_clean_global.head()
# Out:
#                                          uri         artist_names  \
# 573718  spotify:track:6MWtB6iiXyIwun0YzU6DFP          Post Malone
# 573719  spotify:track:2rPE9A1vEgShuZxxzR2tZH        Ariana Grande
# 573720  spotify:track:5p7ujcrUXASCNwRaWNHR1C               Halsey
# 573721  spotify:track:25sgk305KZfyuqVBQIahim              Ava Max
# 573722  spotify:track:1rqqCSm0Qe4I9rUvWncaom  Panic! At The Disco
#
#         artists_num    artist_individual  \
# 573718          1.0          Post Malone
# 573719          1.0        Ariana Grande
# 573720          1.0               Halsey
# 573721          1.0              Ava Max
# 573722          1.0  Panic! At The Disco
#
#                                     artist_id artist_genre  collab  \
# 573718  spotify:artist:246dkjvS1zLTtiykXe5h60          rap       0
# 573719  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR          pop       0
# 573720  spotify:artist:26VFTg2z8YR0cCuwLzESi2   electropop       0
# 573721  spotify:artist:4npEfmQ6YuiwW1GpUmaq3F          pop       0
# 573722  spotify:artist:20JZFwl6HVl6yg8a4H3ZqK  modern rock       0
#
#               track_name  album_num_tracks  peak_rank  weeks_on_chart  \
# 573718              Wow.               1.0          2               4
# 573719     thank u, next               1.0          1              11
# 573720        Without Me               1.0          4              15
# 573721  Sweet but Psycho               1.0          6              16
# 573722        High Hopes              11.0          9              30
#
#          streams       week  danceability  energy   key  mode  loudness  \
# 573718  29944242 2019-01-17         0.833   0.539  11.0   0.0    -7.399
# 573719  27807232 2019-01-17         0.724   0.647   1.0   1.0    -5.642
# 573720  27138512 2019-01-17         0.752   0.488   6.0   1.0    -7.050
# 573721  22400542 2019-01-17         0.719   0.704   1.0   1.0    -4.724
# 573722  19643546 2019-01-17         0.579   0.904   5.0   1.0    -2.729
#
#         acousticness  instrumentalness  liveness  valence    tempo  duration  \
# 573718        0.1630          0.000002    0.1010    0.385   99.947     150.0
# 573719        0.2800          0.000000    0.1020    0.435  106.960     207.0
# 573720        0.2970          0.000009    0.0936    0.533  136.041     202.0
# 573721        0.0691          0.000000    0.1660    0.628  133.002     187.0
# 573722        0.1930          0.000000    0.0640    0.681   82.014     191.0
#
#        country  region language
# 573718  Global  Global   Global
# 573719  Global  Global   Global
# 573720  Global  Global   Global
# 573721  Global  Global   Global
# 573722  Global  Global   Global
