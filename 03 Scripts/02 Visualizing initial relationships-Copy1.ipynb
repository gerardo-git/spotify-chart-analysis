# %% [markdown]
# # Visualizing initial relationships

# %% [markdown]
# ## Contents

# %% [markdown]
# ### 1 Importing Data
# ### 2 Editing dataframe for exploratory analysis
# ### 3 Correlation Matrix Heatmap
# ### 4 Creating Scatter Plots

# %% [markdown]
# ### 1. Importing Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
data_path = r'C:\Users\gerar\CareerFoundry Python\Spotify charts streaming analysis'
df_spotify_clean = pd.read_pickle(os.path.join(data_path, '02 Data', 'Prepared Data', 'spotify_clean_no_global.pkl'))

# %%
df_spotify_clean.shape
# Out:
# (1691599, 27)

# %%
pd.options.display.max_columns = 50
df_spotify_clean.head(50)
# Out:
#                                      uri           artist_names  artists_num  \
# 0   spotify:track:2gpQi3hbcUAcEG8m2dlgfB           Paulo Londra          1.0
# 1   spotify:track:2x8oBuYaObjqHqgGuIUZ0b                    WOS          1.0
# 2   spotify:track:2SJZdZ5DLtlRosJ2xHJJJa           Paulo Londra          1.0
# 3   spotify:track:1O2pcBJGej0pmH2Y9XZMs6                Cris Mj          1.0
# 4   spotify:track:1TpZKxGnHp37ohJRszTSiq                 Emilia          1.0
# 5   spotify:track:4LRPiXqCikLlN15c3yImP7           Harry Styles          1.0
# 6   spotify:track:3EcCc1U405tm8yKm1x6Y8W              La K'onga          1.0
# 7   spotify:track:42Gzfqnfpk7Pp1ydM60eNn          Maria Becerra          1.0
# 8   spotify:track:3FkeNbs9Zeiqkr3WkbOiGp                 Anitta          1.0
# 9   spotify:track:5Us3svqTvNAdnQfEYfoL5g             LIT killah          1.0
# 10  spotify:track:7onMf0QvWgRba2MRxG27yj              La K'onga          1.0
# 11  spotify:track:1UdzJEpgJxtuXAlCOvD4S0            Danny Ocean          1.0
# 12  spotify:track:7JZ5mOTea5T4LH0UdwCsWx                   Duki          1.0
# 13  spotify:track:3GaGWoU1KfVqgl7vnRHP55             C. Tangana          1.0
# 14  spotify:track:2cR9cH9ta7MStHBKs0aOcz            Salastkbron          1.0
# 15  spotify:track:1PmKfNsHxPdMaHP496myD3            Salastkbron          1.0
# 16  spotify:track:1kjs5eR4DMzyB0gm1Z8waV                 Trueno          1.0
# 17  spotify:track:6ylDpki1VpIsc525KC1ojF        Sebastian Yatra          1.0
# 18  spotify:track:1fKFxmSByZfjwVSbq0PHye          Ke Personajes          1.0
# 19  spotify:track:74aGIoQo8pokxzylUTw603              Tiago PZK          1.0
# 20  spotify:track:2rDZhKnPaPG054ExZ6nXUS            Ryan Castro          1.0
# 21  spotify:track:2JPLbjOn0wPCngEot2STUS              Bad Bunny          1.0
# 22  spotify:track:5uHAzGa4d9j35DEbhUwGhi                    WOS          1.0
# 23  spotify:track:3rdAz1fbUfZxYgaCviYhRo         Rauw Alejandro          1.0
# 24  spotify:track:4r9jkMEnArtWGH2rL2FZl0              Bad Bunny          1.0
# 25  spotify:track:75HnDKDqsmEzdOKFWe5FZS           Nathy Peluso          1.0
# 26  spotify:track:3XjN0mvFkQp1FMVM9Ro5hm           Daddy Yankee          1.0
# 4                    pop argentino       0
# 5                              pop       0
# 6                         cuarteto       0
# 7                    pop argentino       0
# 8                         funk pop       0
# 9                argentine hip hop       0
# 10                        cuarteto       0
# 11                           latin       0
# 12               argentine hip hop       0
# 13                  urbano espanol       0
# 14                   pop argentino       0
# 15                   pop argentino       0
# 16               argentine hip hop       0
# 17                           latin       0
# 18                               0       0
# 19                  trap argentino       0
# 20                 trap colombiano       0
# 21                           latin       0
# 22                  trap argentino       0
# 23                     trap latino       0
# 24                           latin       0
# 25                      rap latina       0
# 26                     trap latino       0
# 27                     trap latino       0
# 28                      cumbia 420       0
# 29  concurso de talentos argentino       0
# 30                 argentine indie       0
# 31                  trap argentino       0
# 32                      cumbia 420       0
# 33                   pop argentino       0
# 34                        cuarteto       0
# 35                  r&b en espanol       0
# 36                     trap latino       0
# 37                       latin pop       0
# 38               argentine hip hop       0
# 39                     trap latino       0
# 40                 argentine indie       0
# 41                          cumbia       0
# 42                             pop       0
# 43                  urbano chileno       0
# 44                  argentine rock       0
# 45                     trap latino       0
# 46                 rock en espanol       0
# 47                     trap latino       0
# 48                 rock en espanol       0
# 49                   pop argentino       0
#
#                                    track_name  album_num_tracks  peak_rank  \
# 0                                      Plan A               1.0          1
# 1                                ARRANCARMELO               1.0          2
# 2                                      Chance               2.0          3
# 3                       Una Noche en Medellín               1.0          5
# 4                               cuatro veinte               1.0          6
# 5                                   As It Was               1.0          6
# 6                                 Te Mentiría              14.0         14
# 7                           Felices x Siempre               1.0         11
# 8                                    Envolver              15.0         13
# 9                            La Trampa es Ley               1.0          2
# 10                              El Mismo Aire              18.0         16
# 11                          Fuera del mercado              16.0         26
# 12                                      TOP 5               7.0          3
# 13                         Demasiadas Mujeres              14.0         31
# 14                                      TITAN               1.0          2
# 15                               TURROMANTIKO               1.0         28
# 16                                 DANCE CRIP               1.0          3
# 17                              Tacones Rojos              17.0         21
# 18  Si No Te Tengo / Ángel / Aquello Que Pasó               1.0         29
# 19                           Hablando De Love               1.0         29
# 20                                     Jordan               1.0         49
# 21                                   Yonaguni               1.0          3
# 22                                 MELÓN VINO               7.0          7
# 23                                 Todo De Ti              14.0          1
# 24                                A Tu Merced              20.0         61
# 25                 VIVIR ASÍ ES MORIR DE AMOR               1.0         24
# 26                                   RUMBATÓN              19.0         56
# 27                                    Tal Vez              18.0          1
# 28                                 Tamo Chelo               1.0         33
# 29                                     París               1.0         13
# 30                Seguir Viviendo Sin Tu Amor              15.0         75
# 31                              ALMA DINAMITA               4.0         28
# 32                        Cosas Malas - Remix               1.0         36
# 33                                      Detox               8.0         66
# 34                        Te perdiste mi amor              13.0         71
# 35                                      SAOKO              16.0         81
# 36                                     Sobrio               1.0         22
# 37                              Hasta la Raíz              17.0         66
# 38                                  FEEL ME??               1.0          9
# 39                                      Pepas              25.0          3
# 40                                  ANDRÓMEDA               1.0         54
# 41                                   Inocente              11.0         77
# 42                           Watermelon Sugar              12.0         17
# 43                                     Pégate               1.0        113

# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration             0
# country              0
# region               0
# language             0
# dtype: int64

# %%
# Find duplicates

df_dups = df_spotify_clean[df_spotify_clean.duplicated()]
df_dups.shape

# zero rows -> no duplicates
# Out:
# (0, 27)

# %% [markdown]
# ### 2. Editing Dataframe for exploratory analysis

# %%
df_spotify_clean.columns
# Out:
# Index(['uri', 'artist_names', 'artists_num', 'artist_individual', 'artist_id',
#        'artist_genre', 'collab', 'track_name', 'album_num_tracks', 'peak_rank',
#        'weeks_on_chart', 'streams', 'week', 'danceability', 'energy', 'key',
#        'mode', 'loudness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration', 'country', 'region', 'language'],
#       dtype='object')

# %%
# Drop columns that are not quantitative
df_spotify_quantitative = df_spotify_clean.copy()

df_spotify_quantitative = df_spotify_quantitative.drop(['uri', 'mode', 'artist_names', 'artist_individual',
       'artist_id', 'artist_genre', 'collab', 'key', 'track_name', 'week','country', 'region', 'language'], axis = 1)  

df_spotify_quantitative.head(10)
# Out:
#    artists_num  album_num_tracks  peak_rank  weeks_on_chart  streams  \
# 0          1.0               1.0          1               4  3003411
# 1          1.0               1.0          2               2  2512175
# 2          1.0               2.0          3               2  2408983
# 3          1.0               1.0          5               8  2080139
# 4          1.0               1.0          6               3  1923270
# 5          1.0               1.0          6               2  1555631
# 6          1.0              14.0         14              47  1272870
# 7          1.0               1.0         11               8  1149499
# 8          1.0              15.0         13               6  1104997
# 9          1.0               1.0          2               9  1076236
#
#    danceability  energy  loudness  acousticness  instrumentalness  liveness  \
# 0         0.583   0.834    -4.875        0.0495          0.000000    0.0658
# 1         0.654   0.354    -7.358        0.7240          0.000000    0.1340
# 2         0.721   0.463    -9.483        0.2410          0.000000    0.0929
# 3         0.870   0.548    -5.253        0.0924          0.000046    0.0534
# 4         0.761   0.696    -3.817        0.0811          0.000063    0.1010
# 5         0.520   0.731    -5.338        0.3420          0.001010    0.3110
# 6         0.651   0.731    -6.889        0.1160          0.000000    0.0708
# 7         0.771   0.467    -6.653        0.3750          0.009740    0.1120
# 8         0.812   0.736    -5.421        0.1520          0.002540    0.0914
# 9         0.596   0.710    -5.815        0.2430          0.000000    0.2040
#
#    valence    tempo  duration
# 0    0.557  173.935     178.0
# 1    0.262   81.956     184.0
# 2    0.216  137.915     204.0
# 3    0.832   96.018     154.0
# 4    0.501   95.066     134.0
# 5    0.662  173.930     167.0
# 6    0.653  153.104     218.0
# 7    0.256  100.089     200.0
# 8    0.396   91.993     194.0
# 9    0.632  117.871     142.0

# %%
# rename columns

df_spotify_quantitative.rename(columns={'album_num_tracks': 'album_tracks', 'weeks_on_chart': 'chart_weeks'}, inplace=True)

# %% [markdown]
# ### 3. Correlation Matrix Heatmap

# %%
# Create a correlation matrix using pandas

df_spotify_quantitative.corr()
# Out:
#                   artists_num  album_tracks  peak_rank  chart_weeks   streams  \
# artists_num          1.000000     -0.080728  -0.060807    -0.030762  0.019338
# album_tracks        -0.080728      1.000000  -0.027884     0.153711  0.002414
# peak_rank           -0.060807     -0.027884   1.000000    -0.269936 -0.120056
# chart_weeks         -0.030762      0.153711  -0.269936     1.000000 -0.089761
# streams              0.019338      0.002414  -0.120056    -0.089761  1.000000
# danceability         0.196492     -0.060357  -0.073385    -0.110951 -0.002543
# energy               0.136187     -0.020654   0.023677    -0.081352  0.004313
# loudness             0.107184      0.000274  -0.035063     0.000759  0.025791
# acousticness        -0.099324     -0.037426  -0.002562     0.089091  0.020975
# instrumentalness    -0.044281     -0.023329   0.070582    -0.039415 -0.021424
# liveness             0.012564      0.009902   0.016752    -0.053808  0.028451
# valence              0.138758     -0.035998  -0.003519    -0.050663  0.018314
# tempo                0.035715      0.013722  -0.028403     0.008204  0.016288
# duration             0.424618      0.059723   0.002142     0.158929 -0.017044
#
#                   danceability    energy  loudness  acousticness  \
# artists_num           0.196492  0.136187  0.107184     -0.099324
# album_tracks         -0.060357 -0.020654  0.000274     -0.037426
# peak_rank            -0.073385  0.023677 -0.035063     -0.002562
# chart_weeks          -0.110951 -0.081352  0.000759      0.089091
# streams              -0.002543  0.004313  0.025791      0.020975
# danceability          1.000000  0.185007  0.171996     -0.238141
# energy                0.185007  1.000000  0.681268     -0.542947
# loudness              0.171996  0.681268  1.000000     -0.362119
# acousticness         -0.238141 -0.542947 -0.362119      1.000000
# instrumentalness     -0.048712 -0.017652 -0.145257      0.001022
# liveness             -0.062401  0.113375  0.064844     -0.024252
# valence               0.382992  0.403482  0.346981     -0.193038
# tempo                -0.119990  0.070133  0.040504     -0.050682
# duration             -0.089707 -0.034343 -0.039774      0.032332
#
#                   instrumentalness  liveness   valence     tempo  duration
# artists_num              -0.044281  0.012564  0.138758  0.035715  0.424618
# album_tracks             -0.023329  0.009902 -0.035998  0.013722  0.059723
# peak_rank                 0.070582  0.016752 -0.003519 -0.028403  0.002142
# chart_weeks              -0.039415 -0.053808 -0.050663  0.008204  0.158929
# streams                  -0.021424  0.028451  0.018314  0.016288 -0.017044
# danceability             -0.048712 -0.062401  0.382992 -0.119990 -0.089707
# energy                   -0.017652  0.113375  0.403482  0.070133 -0.034343
# loudness                 -0.145257  0.064844  0.346981  0.040504 -0.039774
# acousticness              0.001022 -0.024252 -0.193038 -0.050682  0.032332
# instrumentalness          1.000000 -0.011710 -0.089080 -0.001470 -0.020823
# liveness                 -0.011710  1.000000  0.038511 -0.052716 -0.019442
# valence                  -0.089080  0.038511  1.000000  0.050092 -0.054341
# tempo                    -0.001470 -0.052716  0.050092  1.000000 -0.005464
# duration                 -0.020823 -0.019442 -0.054341 -0.005464  1.000000

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(11, 11)) # figure size 
plt.matshow(df_spotify_quantitative.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_spotify_quantitative.shape[1]), df_spotify_quantitative.columns, fontsize=8, rotation=58) # x axis labels
plt.yticks(range(df_spotify_quantitative.shape[1]), df_spotify_quantitative.columns, fontsize=8) # y axis labels

cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=8) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title


plt.show()

# %% [markdown]
# ### Insights
#
#
# **"In your face" correlations:** The center of the chart shows strong positive and negative correlations.
#
# Acousticness has a negative correlation with danceability, energy and loudness.
#
# Loudness and energy have a strong positive correlation.
#
# Valence (happiness/positiveness) has strong positive correlations with danceability, energy, and loudness.
#
# **Unexpected behaviors:** it seems very unexpected to me that streams has one of the lowest possible correlations with all the other variables in the chart.
# One explanation could be that first of all, all the songs that reached the charts have a high number of streams.
# Additionally, most songs have a great performance the first weeks or months from their release. Their performance keeps falling with time.
# At the moment I can't fully comprehend its behavior.
#
# **Other:**
# Duration of songs has a somewhat strong positive correlation with number of artists. This makes sense in a way, since the more artists collaborate in a song
# the more time will be needed for each artist to have a highlight.
#
# Peak rank and chart weeks have a mild negative correlation. This makes sense because the "smaller" a peak rank is, the more popular the song will be.
# Thus it will last longer in the charts.
#
# Number of artists and danceability seem to have a mild positive correlation.
#
#
#
# There are other correlations too but as of now I can't think of any other insights.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr = df_spotify_quantitative.corr()

# Create a figure with specific size
plt.figure(figsize=(11, 11))

# Create the heatmap
sns.heatmap(corr, annot=True, fmt=".2f", cmap='Blues', 
            xticklabels=df_spotify_quantitative.columns, 
            yticklabels=df_spotify_quantitative.columns,
            annot_kws={"size": 8})

# Set the title
plt.title('Correlation Matrix', fontsize=14)

# Display the plot
plt.show()

# %%
corr
# Out:
#                   artists_num  album_tracks  peak_rank  chart_weeks   streams  \
# artists_num          1.000000     -0.080728  -0.060807    -0.030762  0.019338
# album_tracks        -0.080728      1.000000  -0.027884     0.153711  0.002414
# peak_rank           -0.060807     -0.027884   1.000000    -0.269936 -0.120056
# chart_weeks         -0.030762      0.153711  -0.269936     1.000000 -0.089761
# streams              0.019338      0.002414  -0.120056    -0.089761  1.000000
# danceability         0.196492     -0.060357  -0.073385    -0.110951 -0.002543
# energy               0.136187     -0.020654   0.023677    -0.081352  0.004313
# loudness             0.107184      0.000274  -0.035063     0.000759  0.025791
# acousticness        -0.099324     -0.037426  -0.002562     0.089091  0.020975
# instrumentalness    -0.044281     -0.023329   0.070582    -0.039415 -0.021424
# liveness             0.012564      0.009902   0.016752    -0.053808  0.028451
# valence              0.138758     -0.035998  -0.003519    -0.050663  0.018314
# tempo                0.035715      0.013722  -0.028403     0.008204  0.016288
# duration             0.424618      0.059723   0.002142     0.158929 -0.017044
#
#                   danceability    energy  loudness  acousticness  \
# artists_num           0.196492  0.136187  0.107184     -0.099324
# album_tracks         -0.060357 -0.020654  0.000274     -0.037426
# peak_rank            -0.073385  0.023677 -0.035063     -0.002562
# chart_weeks          -0.110951 -0.081352  0.000759      0.089091
# streams              -0.002543  0.004313  0.025791      0.020975
# danceability          1.000000  0.185007  0.171996     -0.238141
# energy                0.185007  1.000000  0.681268     -0.542947
# loudness              0.171996  0.681268  1.000000     -0.362119
# acousticness         -0.238141 -0.542947 -0.362119      1.000000
# instrumentalness     -0.048712 -0.017652 -0.145257      0.001022
# liveness             -0.062401  0.113375  0.064844     -0.024252
# valence               0.382992  0.403482  0.346981     -0.193038
# tempo                -0.119990  0.070133  0.040504     -0.050682
# duration             -0.089707 -0.034343 -0.039774      0.032332
#
#                   instrumentalness  liveness   valence     tempo  duration
# artists_num              -0.044281  0.012564  0.138758  0.035715  0.424618
# album_tracks             -0.023329  0.009902 -0.035998  0.013722  0.059723
# peak_rank                 0.070582  0.016752 -0.003519 -0.028403  0.002142
# chart_weeks              -0.039415 -0.053808 -0.050663  0.008204  0.158929
# streams                  -0.021424  0.028451  0.018314  0.016288 -0.017044
# danceability             -0.048712 -0.062401  0.382992 -0.119990 -0.089707
# energy                   -0.017652  0.113375  0.403482  0.070133 -0.034343
# loudness                 -0.145257  0.064844  0.346981  0.040504 -0.039774
# acousticness              0.001022 -0.024252 -0.193038 -0.050682  0.032332
# instrumentalness          1.000000 -0.011710 -0.089080 -0.001470 -0.020823
# liveness                 -0.011710  1.000000  0.038511 -0.052716 -0.019442
# valence                  -0.089080  0.038511  1.000000  0.050092 -0.054341
# tempo                    -0.001470 -0.052716  0.050092  1.000000 -0.005464
# duration                 -0.020823 -0.019442 -0.054341 -0.005464  1.000000

# %% [markdown]
# ### 4. Creating scatter-plots

# %% [markdown]
# ##### 4.1 Duration - Number of artists

# %%
# Create a scatter plot
plt.scatter(df_spotify_quantitative['artists_num'], df_spotify_quantitative['duration'], color ='orange')

# Add labels and title
plt.xlabel('artists_num')
plt.ylabel('duration')
plt.title('Duration and Number of Artists')
# Out:
# Text(0.5, 1.0, 'Duration and Number of Artists')

# %% [markdown]
# Since this is a mild correlation we can't fully assume that there is a strong relationship.
# It is surprising that there are so many songs with more than 5 artists. There seems to be an inflexion point just below 7.5 artists per song.

# %% [markdown]
# ##### 4.2 Acousticness - Energy

# %%
# Create a scatter plot
plt.scatter(df_spotify_quantitative['acousticness'], df_spotify_quantitative['energy'], color = 'darkred')

# Add labels and title
plt.xlabel('acousticness')
plt.ylabel('energy')
plt.title('Acousticness - Energy')
# Out:
# Text(0.5, 1.0, 'Acousticness - Energy')

# %% [markdown]
# The more acoustic a song, the less energy it will have according to the spotify algorithm.
# Production wise this makes sense since EDM and hip hop are genres that have a very low acousticness and the best practices in the production are to make the songs as loud as possible.
#
# These genres are also considered to be high energy genres, more specifically EDM.
#
# The process of making a song loud happens in the mastering stage of a song. There are different mastering thresholds of loudness for different genres.
#
# ***It would be very interesting to see the loudest genres from this dataset!!!**
#
# As a music producer it would also be interesting to know other loudness averages for other genres.

# %% [markdown]
# ##### 4.3 Peak rank - Chart weeks

# %%
# Create a scatter plot
plt.scatter(df_spotify_quantitative['peak_rank'], df_spotify_quantitative['chart_weeks'], color = 'darkred')

# Add labels and title
plt.xlabel('peak_rank')
plt.ylabel('chart_weeks')
plt.title('Peak rank - Chart weeks')
# Out:
# Text(0.5, 1.0, 'Peak rank - Chart weeks')

# %% [markdown]
# Watching the "white space" of the chart, tells us that there are no songs that had a peak rank 175 and lasted more than 150 weeks in the chart.
# A song with a great peak rank such as 10, will slowly descend the charts having more time overall in the charts compared to songs that rank 175 or 200.
# Some songs may reach the charts at rank 200 and never climb any other spot.
# This is one hint that a song will most likely achieve their highest spot in its earliest time, but there is no outstanding proof of this other than intuition and this chart.

# %% [markdown]
# ##### 4.4 Energy - Loudness

# %%
# Create a scatter plot
plt.scatter(df_spotify_quantitative['loudness'], df_spotify_quantitative['energy'], color = 'darkgreen')

# Add labels and title
plt.xlabel('loudness')
plt.ylabel('energy')
plt.title('Loudness - Energy')
# Out:
# Text(0.5, 1.0, 'Loudness - Energy')

# %% [markdown]
# This is no surprise since according to the spotify documentation, loudness is a parameter used to determine energy.

# %%
df_spotify_quantitative.columns
# Out:
# Index(['artists_num', 'album_tracks', 'peak_rank', 'chart_weeks', 'streams',
#        'danceability', 'energy', 'loudness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration'],
#       dtype='object')

# %%
# Create a sub dataframe for the pair plots

sub = df_spotify_quantitative[['peak_rank', 'chart_weeks', 'streams', 'energy', 'duration', 'artists_num']]

# %%
# Plot
g = sns.pairplot(sub)
# Out:
# C:\Users\gerar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gerar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gerar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gerar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gerar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gerar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ##### 5.2 Variables for further examination

# %% [markdown]
# **Groups of variables that work well together:**
#
# Streams - peak rank - chart weeks
#
# **Groups of variables with a mild tendence**
#
# Streams - duration
#
# Chart weeks - duration
#
# Energy - streams

# %% [markdown]
# ### 6. Categorical Plot: Peak rank - chart weeks

# %%
# Create groups/categories

df_spotify_quantitative.loc[df_spotify_quantitative['peak_rank'] < 50, 'rank_tier'] = 'Top'
df_spotify_quantitative.loc[(df_spotify_quantitative['peak_rank'] >= 50) & (df_spotify_quantitative['peak_rank'] < 150), 'rank_tier'] = 'Mid'
df_spotify_quantitative.loc[df_spotify_quantitative['peak_rank'] >= 150, 'rank_tier'] = 'Bottom'

# %%
# Set up the figure and axis
plt.figure(figsize=(10, 6))

# Plot using bar plot
for tier in df_spotify_quantitative['rank_tier'].unique():
    subset = df_spotify_quantitative[df_spotify_quantitative['rank_tier'] == tier]
    plt.scatter(subset['peak_rank'], subset['chart_weeks'], label=tier)

# Add labels and title
plt.xlabel('Peak Rank')
plt.ylabel('Chart Weeks')
plt.title('Peak Rank vs. Chart Weeks')
plt.legend(title='Rank Tier')

plt.show()

# %% [markdown]
# ### 7. Revisiting previous questions with this initial analysis

# %% [markdown]
# Of all the questions that I thought, there is only one that I had insights with this initial analysisl.
#
# **What is the difference between songs with featuring artists and songs without
# featuring artists? Does this reflect in their frequency of reaching the charts.**

# %% [markdown]
# ##### 7.2 Additional questions

# %% [markdown]
# Explore the loudest genres

# %% [markdown]
# Explore number of artists and danceability

# %% [markdown]
# ### 8. Define hypothesis

# %% [markdown]
# A song that has more artists will generally be longer and have higher scores on danceability, valence, energy and loudness.
