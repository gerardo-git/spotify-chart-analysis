# %% [markdown]
# # Global metrics

# %% [markdown]
# ### Import libraries and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
import json

# %%
# This command propts matplotlib visuals to appear in the notebook 

# %matplotlib inline

# %%
# establish data path

data_path = r'C:\Users\gerar\CareerFoundry Python\Spotify charts streaming analysis'

# %%
# import data
df_spotify = pd.read_pickle(os.path.join(data_path, '02 Data', 'Prepared Data', 'spotify_clean_global.pkl'))
geojson_path = r'C:\Users\gerar\CareerFoundry Python\Spotify charts streaming analysis\02 Data\Original Data\world-countries.json'


pd.options.display.max_columns = 50
    
# show
df_spotify.head()
# Out:
#                                          uri         artist_names  \
# 573718  spotify:track:6MWtB6iiXyIwun0YzU6DFP          Post Malone
# 573719  spotify:track:2rPE9A1vEgShuZxxzR2tZH        Ariana Grande
# 573720  spotify:track:5p7ujcrUXASCNwRaWNHR1C               Halsey
# 573721  spotify:track:25sgk305KZfyuqVBQIahim              Ava Max
# 573722  spotify:track:1rqqCSm0Qe4I9rUvWncaom  Panic! At The Disco
#
#         artists_num    artist_individual  \
# 573718          1.0          Post Malone
# 573719          1.0        Ariana Grande
# 573720          1.0               Halsey
# 573721          1.0              Ava Max
# 573722          1.0  Panic! At The Disco
#
#                                     artist_id artist_genre  collab  \
# 573718  spotify:artist:246dkjvS1zLTtiykXe5h60          rap       0
# 573719  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR          pop       0
# 573720  spotify:artist:26VFTg2z8YR0cCuwLzESi2   electropop       0
# ...

# %%
# Drop columns from main dataframe

df_spotify.drop(columns = ['artist_names', 'artist_individual',
       'artist_id', 'artist_genre','collab', 'track_name', 'album_num_tracks', 'key', 'region', 'language'], inplace = True)

# %%
df_spotify.columns
# Out:
# Index(['uri', 'artists_num', 'peak_rank', 'weeks_on_chart', 'streams', 'week',
#        'danceability', 'energy', 'mode', 'loudness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration',
#        'country'],
#       dtype='object')

# %%
# Create copy for each case
df_spotify_uniques = df_spotify[['uri','artists_num', 'peak_rank', 'weeks_on_chart', 'country', 'danceability', 'energy', 'mode', 'loudness',
                                 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                 'duration']].copy()

df_spotify_repeated = df_spotify[['uri','artists_num', 'peak_rank', 'weeks_on_chart', 'country', 'danceability', 'energy', 'mode', 'loudness',
                                 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                 'duration']].copy()

# %%
df_spotify_uniques.drop_duplicates(inplace=True)

# %%
df_spotify_uniques.describe().T
# Out:
#                     count        mean        std        min       25%  \
# artists_num       57994.0    1.654275   0.943219   1.000000    1.0000
# peak_rank         57994.0   44.227179  48.380913   1.000000    7.0000
# weeks_on_chart    57994.0   27.153912  35.633572   1.000000    5.0000
# danceability      57994.0    0.692537   0.136470   0.150000    0.6090
# energy            57994.0    0.635420   0.160866   0.021800    0.5300
# mode              57994.0    0.582664   0.493124   0.000000    0.0000
# loudness          57994.0   -6.090022   2.349233 -34.475000   -7.2450
# acousticness      57994.0    0.237229   0.241172   0.000017    0.0472
# instrumentalness  57994.0    0.007879   0.054373   0.000000    0.0000
# liveness          57994.0    0.167029   0.124958   0.019700    0.0931
# valence           57994.0    0.505951   0.223665   0.032000    0.3370
# tempo             57994.0  120.480035  29.240316  46.718000   96.1720
# ...

# %%
df_spotify_uniques.shape
# Out:
# (6994, 12)
